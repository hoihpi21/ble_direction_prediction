# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import os
import json

# Configuration Variables
FILE_PATH = '19.6.2025.csv'
SELECTED_FEATURES = ['x_snap', 'y_snap', 'timestamp']
LOOK_BACK = 20 # Number of previous time steps to look at for prediction
PREDICT_AHEAD_STEPS = 10 # Number of future time steps to predict

# Data Split Ratios (70% train, 10% validation, 10% test)
TRAIN_RATIO = 0.7
VAL_RATIO = 0.1
TEST_RATIO = 0.1

# Directory for saving outputs
output_result = 'output_result'

# Ensure directories exist
os.makedirs(output_result, exist_ok=True)


# Set device for PyTorch (GPU if available, else CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

print("Starting BLE Direction Prediction Script (PyTorch Notebook Version)...")
print(f"File Path: {FILE_PATH}")
print(f"Selected Features: {SELECTED_FEATURES}")
print(f"Look-back window (input sequence length): {LOOK_BACK}")
print(f"Prediction Horizon (output steps): {PREDICT_AHEAD_STEPS}")
print(f"Data Split: Train {TRAIN_RATIO*100}%, Val {VAL_RATIO*100}%, Test {TEST_RATIO*100}%")
# Out:
# Using device: cpu
# Starting BLE Direction Prediction Script (PyTorch Notebook Version)...
# File Path: 19.6.2025.csv
# Selected Features: ['x_snap', 'y_snap', 'timestamp']
# Look-back window (input sequence length): 20
# Prediction Horizon (output steps): 10
# Data Split: Train 70.0%, Val 10.0%, Test 10.0%

# %% [markdown]
# # 1. Load Data

# %%
print("\n--- 1. Data Loading ---")

# Load the dataset
df = pd.read_csv(FILE_PATH)
df = df[SELECTED_FEATURES]
df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.sort_values(by='timestamp').reset_index(drop=True)
print(f"Data Loaded Successfully. Initial Shape: {df.shape}")
original_df_for_plotting = df.copy() # Keep a copy for plotting original path
# Out:
# --- 1. Data Loading ---
# Data Loaded Successfully. Initial Shape: (105, 3)

# %% [markdown]
# # 2. Data Preprocess

# %%
print("\n--- 2. Data Preprocessing (IQR Outlier Removal and Scaling) ---")
initial_rows = df.shape[0]

# --- IQR Outlier Removal ---
print("  Applying IQR outlier removal for 'x_snap' and 'y_snap'...")
filtered_df = df.copy()
for col in ['x_snap', 'y_snap']:
    Q1 = filtered_df[col].quantile(0.25)
    Q3 = filtered_df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Filter rows where the column value is within the IQR bounds
    filtered_df = filtered_df[(filtered_df[col] >= lower_bound) & (filtered_df[col] <= upper_bound)]

rows_after_filter = filtered_df.shape[0]
print(f"  Removed {initial_rows - rows_after_filter} outliers ({(initial_rows - rows_after_filter)/initial_rows:.2%}).")
print(f"  Data shape after outlier removal: {filtered_df.shape}")

# Plot original path before scaling
plt.figure(figsize=(10, 6))
plt.plot(original_df_for_plotting['x_snap'], original_df_for_plotting['y_snap'], label='Original Path', alpha=0.5)
plt.scatter(original_df_for_plotting['x_snap'].iloc[0], original_df_for_plotting['y_snap'].iloc[0], color='green', s =100, marker='s', label='Start')
plt.scatter(original_df_for_plotting['x_snap'].iloc[-1], original_df_for_plotting['y_snap'].iloc[-1], color='red', s=100, marker='*', label='End')
plt.title('Original Path of BLE Snap Data')
plt.xlabel('X Snap')
plt.ylabel('Y Snap')
plt.legend()
plt.grid()
plt.savefig(os.path.join(output_result, 'original_path.png'))
# Out:
# --- 2. Data Preprocessing (IQR Outlier Removal and Scaling) ---
#   Applying IQR outlier removal for 'x_snap' and 'y_snap'...
#   Removed 0 outliers (0.00%).
#   Data shape after outlier removal: (105, 3)

# %%
# Scaling
data_for_scaling = filtered_df[['x_snap', 'y_snap']].values
n_features = data_for_scaling.shape[1]

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data_for_scaling)
print("  MinMaxScaler applied to x_snap and y_snap.")
# Out:
#   MinMaxScaler applied to x_snap and y_snap.

# %% [markdown]
# # 3. Model Definition

# %%
print("\n--- 3. Defining PyTorch Dataset Class ---")
class BLEDataset(Dataset):
    def __init__(self, data, look_back, predict_ahead_steps):
        self.look_back = look_back
        self.predict_ahead_steps = predict_ahead_steps
        self.X, self.y = self._create_sequences(data)

    def _create_sequences(self, data):
        X, y = [], []
        for i in range(len(data) - self.look_back - self.predict_ahead_steps + 1):
            X.append(data[i:(i + self.look_back), :])
            y.append(data[(i + self.look_back):(i + self.look_back + self.predict_ahead_steps), :].flatten())
        return torch.tensor(np.array(X), dtype=torch.float32), torch.tensor(np.array(y), dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]
print("  BLEDataset class defined.")
# Out:
# --- 3. Defining PyTorch Dataset Class ---
#   BLEDataset class defined.

# %% [markdown]
# # 4. Create Datasets and DataLoaders

# %%
print("\n--- 4. Creating PyTorch Datasets and DataLoaders ---")
full_dataset = BLEDataset(scaled_data, LOOK_BACK, PREDICT_AHEAD_STEPS)

if len(full_dataset) == 0:
    print("Error: Not enough data points to create sequences after preprocessing. Cannot proceed.")
    exit()

total_sequences_in_dataset = len(full_dataset)
train_split_idx = int(total_sequences_in_dataset * TRAIN_RATIO)
val_split_idx = train_split_idx + int(total_sequences_in_dataset * VAL_RATIO)
test_split_idx = val_split_idx + int(total_sequences_in_dataset * TEST_RATIO)
# Out:
# --- 4. Creating PyTorch Datasets and DataLoaders ---

# %%
# Ensure valid splits
if train_split_idx == 0 or val_split_idx <= train_split_idx or test_split_idx <= val_split_idx:
    print(f"Error: Not enough data to create valid train/val/test splits with current ratios ({TRAIN_RATIO}, {VAL_RATIO}, {TEST_RATIO}) and data length ({total_sequences_in_dataset} sequences). Adjust ratios or collect more data.")
    exit()

X_train = full_dataset.X[:train_split_idx]
y_train = full_dataset.y[:train_split_idx]

X_val = full_dataset.X[train_split_idx:val_split_idx]
y_val = full_dataset.y[train_split_idx:val_split_idx]

X_test = full_dataset.X[val_split_idx:test_split_idx]
y_test = full_dataset.y[val_split_idx:test_split_idx]

# %%
# For final prediction: use the very last `LOOK_BACK` actual data points after filtering
if len(scaled_data) < LOOK_BACK:
    print(f"Error: Not enough data ({len(scaled_data)} points) to form the final prediction input sequence (requires {LOOK_BACK} points).")
    exit()
final_predict_input_sequence = torch.tensor(scaled_data[-LOOK_BACK:], dtype=torch.float32).reshape(1, LOOK_BACK, n_features)

print(f"  Train set shape (X, y): {X_train.shape}, {y_train.shape}")
print(f"  Validation set shape (X, y): {X_val.shape}, {y_val.shape}")
print(f"  Test set shape (X, y): {X_test.shape}, {y_test.shape}")
print(f"  Final prediction input sequence shape: {final_predict_input_sequence.shape}")
print(f"  Note: The final prediction input uses the last '{LOOK_BACK}' available actual data points after filtering.")
# Out:
#   Train set shape (X, y): torch.Size([53, 20, 2]), torch.Size([53, 20])
#   Validation set shape (X, y): torch.Size([7, 20, 2]), torch.Size([7, 20])
#   Test set shape (X, y): torch.Size([7, 20, 2]), torch.Size([7, 20])
#   Final prediction input sequence shape: torch.Size([1, 20, 2])
#   Note: The final prediction input uses the last '20' available actual data points after filtering.

# %% [markdown]
# # 5. Define Model Class Class

# %%
print("\n--- 5. Defining PyTorch LSTM Model Class ---")
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=2, dropout_rate=0.2):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.lstm1 = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.dropout1 = nn.Dropout(dropout_rate)
        
        self.lstm2 = nn.LSTM(hidden_size, hidden_size, batch_first=True) 
        self.dropout2 = nn.Dropout(dropout_rate)

        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0_1 = torch.zeros(1, x.size(0), self.hidden_size).to(device)
        c0_1 = torch.zeros(1, x.size(0), self.hidden_size).to(device)
        out1, _ = self.lstm1(x, (h0_1, c0_1))
        out1 = self.dropout1(out1)

        h0_2 = torch.zeros(1, out1.size(0), self.hidden_size).to(device)
        c0_2 = torch.zeros(1, out1.size(0), self.hidden_size).to(device)
        out2, _ = self.lstm2(out1, (h0_2, c0_2)) 
        out_last_step = out2[:, -1, :] # Take the last element of the sequence dimension

        out = self.fc(out_last_step)
        return out
print("  LSTMModel class defined.")
# Out:
# --- 5. Defining PyTorch LSTM Model Class ---
#   LSTMModel class defined.

# %% [markdown]
# # 6. Model Training Loop (Iterate Optimizers)

# %%
# --- Cell 7: Model Training Loop (Iterate Optimizers) ---
print("\n--- 7. Model Training Loop (Iterating Optimizers) ---")

input_size = n_features # Number of features per time step (x, y)
output_size = PREDICT_AHEAD_STEPS * n_features # Flattened output (10 * 2 = 20)
hidden_size = 100 # Consistent with previous examples
epochs = 50
batch_size = 32

optimizers_to_test = ['adam', 'sgd', 'adamw', 'rmsprop', 'adagrad']
all_histories = {}
best_optimizer_name = None
best_model_state_dict_path = None


train_dataset_loader = DataLoader(torch.utils.data.TensorDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
val_dataset_loader = DataLoader(torch.utils.data.TensorDataset(X_val, y_val), batch_size=batch_size, shuffle=False)
test_dataset_loader = DataLoader(torch.utils.data.TensorDataset(X_test, y_test), batch_size=batch_size, shuffle=False) # For evaluation later
# Out:
# --- 7. Model Training Loop (Iterating Optimizers) ---

# %%
for opt_name in optimizers_to_test:
    print(f"\n===== Training with Optimizer: {opt_name.upper()} =====")
    
    # Instantiate Model for current optimizer
    model = LSTMModel(input_size, hidden_size, output_size).to(device)

    # Define Optimizer and Loss Function
    if opt_name == 'adam':
        optimizer = torch.optim.Adam(model.parameters())
    elif opt_name == 'sgd':
        optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
    elif opt_name == 'adamw':
        optimizer = torch.optim.AdamW(model.parameters())
    elif opt_name == 'rmsprop':
        optimizer = torch.optim.RMSprop(model.parameters())
    elif opt_name == 'adagrad':
        optimizer = torch.optim.Adagrad(model.parameters())
    
    criterion = nn.MSELoss()

    history = {'loss': [], 'val_loss': []}
    current_best_val_loss_for_optimizer = float('inf')
    patience_counter = 0

    for epoch in range(epochs):
        # --- Training Phase ---
        model.train()
        total_train_loss = 0
        for batch_X, batch_y in train_dataset_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)

            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

        avg_train_loss = total_train_loss / len(train_dataset_loader)
        history['loss'].append(avg_train_loss)

         # --- Validation Phase ---
        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for batch_X_val, batch_y_val in val_dataset_loader:
                batch_X_val, batch_y_val = batch_X_val.to(device), batch_y_val.to(device)
                outputs_val = model(batch_X_val)
                val_loss = criterion(outputs_val, batch_y_val)
                total_val_loss += val_loss.item()
                
        avg_val_loss = total_val_loss / len(val_dataset_loader)
        history['val_loss'].append(avg_val_loss)

        print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')

        # --- Early Stopping ---
        if avg_val_loss < current_best_val_loss_for_optimizer:
            current_best_val_loss_for_optimizer = avg_val_loss
            patience_counter = 0
            
        else:
            patience_counter += 1
            if patience_counter >= 10:
                print(f"Early stopping at epoch {epoch+1} as validation loss did not improve for 10 epochs.")
            
        print(f"Training with {opt_name.upper()} completed.")

                # Evaluate model on Test Set
        print(f"  Running Inference for {opt_name.upper()} on Test Set...")
        model.eval()
        total_test_loss = 0
        with torch.no_grad():
            for batch_X_test, batch_y_test in test_dataset_loader:
                batch_X_test, batch_y_test = batch_X_test.to(device), batch_y_test.to(device)
                outputs_test = model(batch_X_test)
                test_loss = criterion(outputs_test, batch_y_test)
                total_test_loss += test_loss.item()
            
        avg_test_loss = total_test_loss / len(test_dataset_loader)
        print(f"  Test Loss for {opt_name.upper()}: {avg_test_loss:.4f}")

        # --- Save Training History as JSON ---
        history_data = {key: [float(val) for val in values] for key, values in history.items()}
        history_path = os.path.join(output_result, f'history_{opt_name}.json')
        with open(history_path, 'w') as f:
            json.dump(history_data, f)
        print(f"  Training history saved for {opt_name.upper()} at: {history_path}")

        # --- Save Model State Dict (ALWAYS) ---
        model_save_path = os.path.join(output_result, f'model_{opt_name}.pth')
        torch.save(model.state_dict(), model_save_path)
        print(f"  ✅ Model saved for {opt_name.upper()} at: {model_save_path}")
    
    all_histories[opt_name] = history
# Out:
# ===== Training with Optimizer: ADAM =====
# Epoch [1/50], Train Loss: 0.3943, Val Loss: 0.5875
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.2222
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [2/50], Train Loss: 0.3887, Val Loss: 0.5527
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.2019
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [3/50], Train Loss: 0.3553, Val Loss: 0.5120
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.1785
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [4/50], Train Loss: 0.3169, Val Loss: 0.4587
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.1490
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [5/50], Train Loss: 0.2773, Val Loss: 0.3796
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.1098
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [6/50], Train Loss: 0.2211, Val Loss: 0.2529
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0707
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [7/50], Train Loss: 0.1462, Val Loss: 0.1052
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.1352
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [8/50], Train Loss: 0.1647, Val Loss: 0.0735
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.1764
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [9/50], Train Loss: 0.1533, Val Loss: 0.0737
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.1113
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [10/50], Train Loss: 0.1135, Val Loss: 0.1092
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0623
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [11/50], Train Loss: 0.1116, Val Loss: 0.1431
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0488
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [12/50], Train Loss: 0.1119, Val Loss: 0.1486
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0471
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [13/50], Train Loss: 0.1121, Val Loss: 0.1340
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0481
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [14/50], Train Loss: 0.1082, Val Loss: 0.1094
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0525
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [15/50], Train Loss: 0.1025, Val Loss: 0.0855
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0609
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [16/50], Train Loss: 0.1018, Val Loss: 0.0699
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0693
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [17/50], Train Loss: 0.1002, Val Loss: 0.0634
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0719
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [18/50], Train Loss: 0.0986, Val Loss: 0.0640
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0675
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [19/50], Train Loss: 0.0972, Val Loss: 0.0693
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0603
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [20/50], Train Loss: 0.0953, Val Loss: 0.0758
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0546
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [21/50], Train Loss: 0.0947, Val Loss: 0.0805
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0526
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [22/50], Train Loss: 0.0933, Val Loss: 0.0812
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0539
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [23/50], Train Loss: 0.0919, Val Loss: 0.0808
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0548
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [24/50], Train Loss: 0.0910, Val Loss: 0.0793
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0547
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [25/50], Train Loss: 0.0884, Val Loss: 0.0764
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0543
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [26/50], Train Loss: 0.0878, Val Loss: 0.0717
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0531
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [27/50], Train Loss: 0.0850, Val Loss: 0.0660
# Early stopping at epoch 27 as validation loss did not improve for 10 epochs.
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0512
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [28/50], Train Loss: 0.0815, Val Loss: 0.0588
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0512
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [29/50], Train Loss: 0.0779, Val Loss: 0.0579
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0419
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [30/50], Train Loss: 0.0740, Val Loss: 0.0496
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0466
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [31/50], Train Loss: 0.0688, Val Loss: 0.0454
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0404
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [32/50], Train Loss: 0.0630, Val Loss: 0.0401
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0309
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [33/50], Train Loss: 0.0584, Val Loss: 0.0332
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0400
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [34/50], Train Loss: 0.0548, Val Loss: 0.0277
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0234
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [35/50], Train Loss: 0.0464, Val Loss: 0.0234
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0184
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [36/50], Train Loss: 0.0424, Val Loss: 0.0218
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0192
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [37/50], Train Loss: 0.0419, Val Loss: 0.0159
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0160
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [38/50], Train Loss: 0.0366, Val Loss: 0.0157
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0268
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [39/50], Train Loss: 0.0345, Val Loss: 0.0173
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0127
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [40/50], Train Loss: 0.0329, Val Loss: 0.0159
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0133
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [41/50], Train Loss: 0.0292, Val Loss: 0.0137
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0201
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [42/50], Train Loss: 0.0271, Val Loss: 0.0175
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0138
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [43/50], Train Loss: 0.0235, Val Loss: 0.0200
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0124
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [44/50], Train Loss: 0.0217, Val Loss: 0.0133
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0140
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [45/50], Train Loss: 0.0191, Val Loss: 0.0124
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0140
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [46/50], Train Loss: 0.0194, Val Loss: 0.0121
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0129
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [47/50], Train Loss: 0.0186, Val Loss: 0.0118
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0135
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [48/50], Train Loss: 0.0194, Val Loss: 0.0114
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0125
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [49/50], Train Loss: 0.0175, Val Loss: 0.0110
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0129
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
# Epoch [50/50], Train Loss: 0.0169, Val Loss: 0.0099
# Training with ADAM completed.
#   Running Inference for ADAM on Test Set...
#   Test Loss for ADAM: 0.0144
#   Training history saved for ADAM at: output_result/history_adam.json
#   ✅ Model saved for ADAM at: output_result/model_adam.pth
#
# ===== Training with Optimizer: SGD =====
# Epoch [1/50], Train Loss: 0.4255, Val Loss: 0.6278
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2455
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [2/50], Train Loss: 0.4073, Val Loss: 0.6253
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2441
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [3/50], Train Loss: 0.4272, Val Loss: 0.6229
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2426
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [4/50], Train Loss: 0.4135, Val Loss: 0.6204
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2412
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [5/50], Train Loss: 0.4177, Val Loss: 0.6180
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2398
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [6/50], Train Loss: 0.4147, Val Loss: 0.6155
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2384
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [7/50], Train Loss: 0.3963, Val Loss: 0.6132
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2370
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [8/50], Train Loss: 0.4130, Val Loss: 0.6108
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2356
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [9/50], Train Loss: 0.4095, Val Loss: 0.6084
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2342
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [10/50], Train Loss: 0.4115, Val Loss: 0.6060
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2328
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [11/50], Train Loss: 0.4097, Val Loss: 0.6036
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2315
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [12/50], Train Loss: 0.3996, Val Loss: 0.6013
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2301
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [13/50], Train Loss: 0.4052, Val Loss: 0.5989
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2287
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [14/50], Train Loss: 0.4045, Val Loss: 0.5966
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2274
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [15/50], Train Loss: 0.4065, Val Loss: 0.5942
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2261
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [16/50], Train Loss: 0.3995, Val Loss: 0.5919
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2247
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [17/50], Train Loss: 0.3849, Val Loss: 0.5896
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2234
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [18/50], Train Loss: 0.3894, Val Loss: 0.5874
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2221
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [19/50], Train Loss: 0.3899, Val Loss: 0.5851
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2208
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [20/50], Train Loss: 0.3870, Val Loss: 0.5828
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2195
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [21/50], Train Loss: 0.3779, Val Loss: 0.5806
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2183
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [22/50], Train Loss: 0.4017, Val Loss: 0.5783
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2170
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [23/50], Train Loss: 0.3921, Val Loss: 0.5760
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2157
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [24/50], Train Loss: 0.3988, Val Loss: 0.5737
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2144
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [25/50], Train Loss: 0.3764, Val Loss: 0.5715
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2132
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [26/50], Train Loss: 0.3877, Val Loss: 0.5693
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2119
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [27/50], Train Loss: 0.3857, Val Loss: 0.5671
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2107
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [28/50], Train Loss: 0.3769, Val Loss: 0.5649
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2094
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [29/50], Train Loss: 0.3747, Val Loss: 0.5627
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2082
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [30/50], Train Loss: 0.3776, Val Loss: 0.5605
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2070
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [31/50], Train Loss: 0.3716, Val Loss: 0.5583
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2058
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [32/50], Train Loss: 0.3664, Val Loss: 0.5562
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2046
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [33/50], Train Loss: 0.3585, Val Loss: 0.5541
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2034
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [34/50], Train Loss: 0.3713, Val Loss: 0.5519
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2022
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [35/50], Train Loss: 0.3744, Val Loss: 0.5498
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.2010
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [36/50], Train Loss: 0.3623, Val Loss: 0.5477
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1998
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [37/50], Train Loss: 0.3633, Val Loss: 0.5455
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1987
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [38/50], Train Loss: 0.3541, Val Loss: 0.5435
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1975
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [39/50], Train Loss: 0.3640, Val Loss: 0.5414
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1964
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [40/50], Train Loss: 0.3625, Val Loss: 0.5393
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1952
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [41/50], Train Loss: 0.3594, Val Loss: 0.5372
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1941
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [42/50], Train Loss: 0.3558, Val Loss: 0.5351
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1929
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [43/50], Train Loss: 0.3603, Val Loss: 0.5330
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1918
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [44/50], Train Loss: 0.3541, Val Loss: 0.5310
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1907
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [45/50], Train Loss: 0.3461, Val Loss: 0.5290
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1896
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [46/50], Train Loss: 0.3594, Val Loss: 0.5269
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1885
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [47/50], Train Loss: 0.3564, Val Loss: 0.5248
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1873
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [48/50], Train Loss: 0.3292, Val Loss: 0.5229
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1863
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [49/50], Train Loss: 0.3409, Val Loss: 0.5209
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1852
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
# Epoch [50/50], Train Loss: 0.3419, Val Loss: 0.5189
# Training with SGD completed.
#   Running Inference for SGD on Test Set...
#   Test Loss for SGD: 0.1841
#   Training history saved for SGD at: output_result/history_sgd.json
#   ✅ Model saved for SGD at: output_result/model_sgd.pth
#
# ===== Training with Optimizer: ADAMW =====
# Epoch [1/50], Train Loss: 0.4053, Val Loss: 0.5903
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.2258
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [2/50], Train Loss: 0.3826, Val Loss: 0.5529
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.2036
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [3/50], Train Loss: 0.3516, Val Loss: 0.5065
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.1768
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [4/50], Train Loss: 0.3170, Val Loss: 0.4405
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.1408
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [5/50], Train Loss: 0.2751, Val Loss: 0.3363
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0934
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [6/50], Train Loss: 0.1956, Val Loss: 0.1801
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0690
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [7/50], Train Loss: 0.1367, Val Loss: 0.0794
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.1529
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [8/50], Train Loss: 0.1436, Val Loss: 0.0611
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.1347
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [9/50], Train Loss: 0.1234, Val Loss: 0.0700
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0830
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [10/50], Train Loss: 0.1019, Val Loss: 0.0976
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0561
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [11/50], Train Loss: 0.1025, Val Loss: 0.1185
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0493
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [12/50], Train Loss: 0.1082, Val Loss: 0.1214
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0497
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [13/50], Train Loss: 0.1090, Val Loss: 0.1084
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0538
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [14/50], Train Loss: 0.1022, Val Loss: 0.0890
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0621
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [15/50], Train Loss: 0.1022, Val Loss: 0.0734
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0709
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [16/50], Train Loss: 0.0984, Val Loss: 0.0664
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0753
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [17/50], Train Loss: 0.0996, Val Loss: 0.0625
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0761
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [18/50], Train Loss: 0.0976, Val Loss: 0.0663
# Early stopping at epoch 18 as validation loss did not improve for 10 epochs.
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0695
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [19/50], Train Loss: 0.0944, Val Loss: 0.0727
# Early stopping at epoch 19 as validation loss did not improve for 10 epochs.
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0625
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [20/50], Train Loss: 0.0944, Val Loss: 0.0777
# Early stopping at epoch 20 as validation loss did not improve for 10 epochs.
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0580
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [21/50], Train Loss: 0.0922, Val Loss: 0.0801
# Early stopping at epoch 21 as validation loss did not improve for 10 epochs.
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0565
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [22/50], Train Loss: 0.0939, Val Loss: 0.0809
# Early stopping at epoch 22 as validation loss did not improve for 10 epochs.
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0554
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [23/50], Train Loss: 0.0920, Val Loss: 0.0767
# Early stopping at epoch 23 as validation loss did not improve for 10 epochs.
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0565
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [24/50], Train Loss: 0.0898, Val Loss: 0.0709
# Early stopping at epoch 24 as validation loss did not improve for 10 epochs.
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0580
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [25/50], Train Loss: 0.0885, Val Loss: 0.0661
# Early stopping at epoch 25 as validation loss did not improve for 10 epochs.
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0582
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [26/50], Train Loss: 0.0861, Val Loss: 0.0631
# Early stopping at epoch 26 as validation loss did not improve for 10 epochs.
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0560
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [27/50], Train Loss: 0.0838, Val Loss: 0.0621
# Early stopping at epoch 27 as validation loss did not improve for 10 epochs.
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0508
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [28/50], Train Loss: 0.0796, Val Loss: 0.0613
# Early stopping at epoch 28 as validation loss did not improve for 10 epochs.
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0461
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [29/50], Train Loss: 0.0759, Val Loss: 0.0566
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0418
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [30/50], Train Loss: 0.0699, Val Loss: 0.0479
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0387
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [31/50], Train Loss: 0.0642, Val Loss: 0.0369
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0401
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [32/50], Train Loss: 0.0565, Val Loss: 0.0358
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0435
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [33/50], Train Loss: 0.0559, Val Loss: 0.0281
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0277
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [34/50], Train Loss: 0.0522, Val Loss: 0.0232
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0247
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [35/50], Train Loss: 0.0462, Val Loss: 0.0209
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0223
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [36/50], Train Loss: 0.0447, Val Loss: 0.0153
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0228
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [37/50], Train Loss: 0.0463, Val Loss: 0.0151
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0256
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [38/50], Train Loss: 0.0411, Val Loss: 0.0169
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0186
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [39/50], Train Loss: 0.0393, Val Loss: 0.0164
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0174
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [40/50], Train Loss: 0.0337, Val Loss: 0.0118
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0224
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [41/50], Train Loss: 0.0309, Val Loss: 0.0128
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0171
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [42/50], Train Loss: 0.0266, Val Loss: 0.0184
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0190
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [43/50], Train Loss: 0.0268, Val Loss: 0.0147
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0164
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [44/50], Train Loss: 0.0227, Val Loss: 0.0133
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0144
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [45/50], Train Loss: 0.0232, Val Loss: 0.0132
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0122
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [46/50], Train Loss: 0.0201, Val Loss: 0.0137
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0143
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [47/50], Train Loss: 0.0203, Val Loss: 0.0135
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0139
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [48/50], Train Loss: 0.0185, Val Loss: 0.0140
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0149
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [49/50], Train Loss: 0.0194, Val Loss: 0.0131
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0143
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
# Epoch [50/50], Train Loss: 0.0170, Val Loss: 0.0132
# Early stopping at epoch 50 as validation loss did not improve for 10 epochs.
# Training with ADAMW completed.
#   Running Inference for ADAMW on Test Set...
#   Test Loss for ADAMW: 0.0163
#   Training history saved for ADAMW at: output_result/history_adamw.json
#   ✅ Model saved for ADAMW at: output_result/model_adamw.pth
#
# ===== Training with Optimizer: RMSPROP =====
# Epoch [1/50], Train Loss: 11.0304, Val Loss: 1.3705
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.7799
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [2/50], Train Loss: 2.3431, Val Loss: 1.7556
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.9891
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [3/50], Train Loss: 0.8425, Val Loss: 0.0535
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.1171
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [4/50], Train Loss: 0.1083, Val Loss: 0.0560
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.0826
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [5/50], Train Loss: 0.0987, Val Loss: 0.0983
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.0418
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [6/50], Train Loss: 0.1000, Val Loss: 0.0732
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.0652
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [7/50], Train Loss: 0.0984, Val Loss: 0.1041
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.0457
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [8/50], Train Loss: 0.0993, Val Loss: 0.0567
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.0879
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [9/50], Train Loss: 0.0982, Val Loss: 0.0684
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.0588
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [10/50], Train Loss: 0.0980, Val Loss: 0.0751
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.0527
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [11/50], Train Loss: 0.0995, Val Loss: 0.0633
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.0785
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [12/50], Train Loss: 0.1047, Val Loss: 0.1174
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.0565
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [13/50], Train Loss: 0.1005, Val Loss: 0.0883
# Early stopping at epoch 13 as validation loss did not improve for 10 epochs.
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.0581
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [14/50], Train Loss: 0.0964, Val Loss: 0.0805
# Early stopping at epoch 14 as validation loss did not improve for 10 epochs.
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.0613
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# ...
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
# Epoch [50/50], Train Loss: 0.0981, Val Loss: 0.0636
# Early stopping at epoch 50 as validation loss did not improve for 10 epochs.
# Training with RMSPROP completed.
#   Running Inference for RMSPROP on Test Set...
#   Test Loss for RMSPROP: 0.0574
#   Training history saved for RMSPROP at: output_result/history_rmsprop.json
#   ✅ Model saved for RMSPROP at: output_result/model_rmsprop.pth
#
# ===== Training with Optimizer: ADAGRAD =====
# Epoch [1/50], Train Loss: 0.3488, Val Loss: 0.2625
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.6785
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [2/50], Train Loss: 0.3242, Val Loss: 0.1042
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0667
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [3/50], Train Loss: 0.1046, Val Loss: 0.0801
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0754
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [4/50], Train Loss: 0.0994, Val Loss: 0.1024
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0556
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [5/50], Train Loss: 0.0988, Val Loss: 0.0807
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0680
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [6/50], Train Loss: 0.0954, Val Loss: 0.0746
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0651
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [7/50], Train Loss: 0.0953, Val Loss: 0.0952
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0516
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [8/50], Train Loss: 0.0951, Val Loss: 0.0647
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0802
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [9/50], Train Loss: 0.0864, Val Loss: 0.0866
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0318
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [10/50], Train Loss: 0.0874, Val Loss: 0.0849
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0247
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [11/50], Train Loss: 0.0762, Val Loss: 0.0674
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0206
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [12/50], Train Loss: 0.1051, Val Loss: 0.0664
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0305
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [13/50], Train Loss: 0.0686, Val Loss: 0.0481
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0201
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [14/50], Train Loss: 0.0470, Val Loss: 0.0305
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0343
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [15/50], Train Loss: 0.0850, Val Loss: 0.0454
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0120
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [16/50], Train Loss: 0.0429, Val Loss: 0.0268
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0139
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [17/50], Train Loss: 0.0433, Val Loss: 0.0367
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0195
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [18/50], Train Loss: 0.0394, Val Loss: 0.0317
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0355
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [19/50], Train Loss: 0.0568, Val Loss: 0.0245
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0185
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [20/50], Train Loss: 0.0253, Val Loss: 0.0142
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0226
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [21/50], Train Loss: 0.0210, Val Loss: 0.0116
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0106
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [22/50], Train Loss: 0.0197, Val Loss: 0.0111
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0129
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [23/50], Train Loss: 0.0190, Val Loss: 0.0105
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0073
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [24/50], Train Loss: 0.0239, Val Loss: 0.0154
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0223
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [25/50], Train Loss: 0.0263, Val Loss: 0.0115
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0092
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [26/50], Train Loss: 0.0160, Val Loss: 0.0099
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0096
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [27/50], Train Loss: 0.0144, Val Loss: 0.0102
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0095
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [28/50], Train Loss: 0.0144, Val Loss: 0.0110
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0144
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [29/50], Train Loss: 0.0140, Val Loss: 0.0097
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0107
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [30/50], Train Loss: 0.0137, Val Loss: 0.0100
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0100
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [31/50], Train Loss: 0.0138, Val Loss: 0.0103
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0107
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [32/50], Train Loss: 0.0143, Val Loss: 0.0106
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0095
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [33/50], Train Loss: 0.0156, Val Loss: 0.0103
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0086
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [34/50], Train Loss: 0.0127, Val Loss: 0.0113
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0120
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [35/50], Train Loss: 0.0120, Val Loss: 0.0109
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0131
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [36/50], Train Loss: 0.0124, Val Loss: 0.0099
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0090
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [37/50], Train Loss: 0.0128, Val Loss: 0.0107
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0099
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [38/50], Train Loss: 0.0120, Val Loss: 0.0096
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0090
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [39/50], Train Loss: 0.0123, Val Loss: 0.0107
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0105
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [40/50], Train Loss: 0.0151, Val Loss: 0.0116
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0113
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [41/50], Train Loss: 0.0170, Val Loss: 0.0098
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0111
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [42/50], Train Loss: 0.0134, Val Loss: 0.0109
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0089
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [43/50], Train Loss: 0.0124, Val Loss: 0.0113
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0108
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [44/50], Train Loss: 0.0145, Val Loss: 0.0120
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0100
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [45/50], Train Loss: 0.0155, Val Loss: 0.0123
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0085
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [46/50], Train Loss: 0.0138, Val Loss: 0.0107
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0096
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [47/50], Train Loss: 0.0111, Val Loss: 0.0107
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0095
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [48/50], Train Loss: 0.0108, Val Loss: 0.0104
# Early stopping at epoch 48 as validation loss did not improve for 10 epochs.
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0107
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [49/50], Train Loss: 0.0105, Val Loss: 0.0113
# Early stopping at epoch 49 as validation loss did not improve for 10 epochs.
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0108
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth
# Epoch [50/50], Train Loss: 0.0099, Val Loss: 0.0116
# Early stopping at epoch 50 as validation loss did not improve for 10 epochs.
# Training with ADAGRAD completed.
#   Running Inference for ADAGRAD on Test Set...
#   Test Loss for ADAGRAD: 0.0119
#   Training history saved for ADAGRAD at: output_result/history_adagrad.json
#   ✅ Model saved for ADAGRAD at: output_result/model_adagrad.pth

# %% [markdown]
# # 7. Plotting

# %%
print("\n--- 7. Plotting Results ---")

# Plotting individual training histories
for opt_name, history in all_histories.items():
    plt.figure(figsize=(10, 6))
    plt.plot(history['loss'], label='Training Loss')
    plt.plot(history['val_loss'], label='Validation Loss')
    plt.title(f'Training and Validation Loss for {opt_name.upper()}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss (MSE)')
    plt.legend()
    plt.grid(True)
    plot_path = os.path.join(output_result, f'loss_plot_{opt_name}.png')
    plt.savefig(plot_path)
    plt.close()
    print(f"  Loss plot for {opt_name.upper()} saved at: {plot_path}")

print('\nHistories available for plotting:', list(all_histories.keys()))
# Out:
# --- 7. Plotting Results ---
#   Loss plot for ADAM saved at: output_result/loss_plot_adam.png
#   Loss plot for SGD saved at: output_result/loss_plot_sgd.png
#   Loss plot for ADAMW saved at: output_result/loss_plot_adamw.png
#   Loss plot for RMSPROP saved at: output_result/loss_plot_rmsprop.png
#   Loss plot for ADAGRAD saved at: output_result/loss_plot_adagrad.png
#
# Histories available for plotting: ['adam', 'sgd', 'adamw', 'rmsprop', 'adagrad']

# %%
# Plotting all training losses for comparison
plt.figure(figsize=(12, 8))
for opt_name, history in all_histories.items():
    plt.plot(history['loss'], label=f'{opt_name.upper()} Training Loss')
plt.title('Comparison of Training Losses Across Optimizers')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plot_path = os.path.join(output_result, 'all_training_losses_comparison.png')
plt.savefig(plot_path)
plt.close()
print(f"  Comparison plot of all training losses saved at: {plot_path}")
# Out:
#   Comparison plot of all training losses saved at: output_result/all_training_losses_comparison.png

# %% [markdown]
# # 8. Prediction

# %%
# Load model
final_model = LSTMModel(input_size, hidden_size, output_size).to(device)
final_model.load_state_dict(torch.load(model_save_path))
final_model.eval()
final_predict_input_sequence = X_test[-1].unsqueeze(0)  # Reshape to (1, LOOK_BACK, n_features)
y_ground = y_test[-1]  # Get the last ground truth for comparison

print(f"Predicting next {PREDICT_AHEAD_STEPS} steps...")
final_predict_input_sequence = final_predict_input_sequence.to(device)

with torch.no_grad():
    predicted_scaled_tensor = final_model(final_predict_input_sequence)

predicted_scaled = predicted_scaled_tensor.cpu().numpy()
predicted_scaled = predicted_scaled.reshape(PREDICT_AHEAD_STEPS, n_features)

# Inverse transform to original scale
predicted_coords = scaler.inverse_transform(predicted_scaled)

# Ground truth for Comparison
true_coords = scaler.inverse_transform(y_ground.cpu().numpy().reshape(-1, n_features))

# Compute per-step errors (Euclidean Distance)
errors = np.linalg.norm(predicted_coords - true_coords, axis=1)  #shape:(10,)
mean_error = np.mean(errors)
max_error = np.max(errors)

# Print Comparison
print('\n -- Ground Trutth vs Predicted (10 steps ahead) ---')
for i in range(PREDICT_AHEAD_STEPS):
    pred = predicted_coords[i]
    truth = true_coords[i]
    err = errors[i]
    print(f"Step {i+1}: GT=({truth[0]:.2f}, {truth[1]:.2f}) | Pred=({pred[0]:.2f}, {pred[1]:.2f}) | Error={err:.2f}")
print(f"\nMean Error: {mean_error:.2f}, Max Error: {max_error:.2f}")
# Plotting the predicted path

plt.figure(figsize=(10, 6))
plt.plot(original_df_for_plotting['x_snap'], original_df_for_plotting['y_snap'], label='Original Path', alpha=0.5)
plt.scatter(original_df_for_plotting['x_snap'].iloc[0], original_df_for_plotting['y_snap'].iloc[0], color='green', s=100, marker='s', label='Start')
plt.scatter(original_df_for_plotting['x_snap'].iloc[-1], original_df_for_plotting['y_snap'].iloc[-1], color='red', s=100, marker='*', label='End')
# Plot predicted path
predicted_df = pd.DataFrame(predicted_coords, columns=['x_snap', 'y_snap'])
plt.plot(predicted_df['x_snap'], predicted_df['y_snap'], label='Predicted Path', color='orange', linestyle='--')
plt.scatter(predicted_df['x_snap'].iloc[0], predicted_df['y_snap'].iloc[0], color='blue', s=100, marker='o', label='Predicted Start')
plt.scatter(predicted_df['x_snap'].iloc[-1], predicted_df['y_snap'].iloc[-1], color='purple', s=100, marker='x', label='Predicted End')
plt.title('Predicted Path of BLE Snap Data')
plt.xlabel('X Snap')
plt.ylabel('Y Snap')
plt.legend()
plt.grid()
# Out:
# Predicting next 10 steps...
#
#  -- Ground Trutth vs Predicted (10 steps ahead) ---
# Step 1: GT=(35.27, 23.99) | Pred=(36.49, 23.99) | Error=1.22
# Step 2: GT=(34.99, 24.19) | Pred=(33.07, 23.10) | Error=2.20
# Step 3: GT=(30.03, 19.02) | Pred=(32.27, 22.03) | Error=3.76
# Step 4: GT=(29.56, 18.52) | Pred=(30.61, 21.24) | Error=2.92
# Step 5: GT=(34.44, 17.14) | Pred=(31.81, 20.17) | Error=4.01
# Step 6: GT=(39.49, 18.07) | Pred=(31.80, 19.23) | Error=7.78
# Step 7: GT=(39.93, 17.92) | Pred=(33.94, 18.19) | Error=6.00
# Step 8: GT=(46.54, 16.02) | Pred=(36.27, 17.67) | Error=10.40
# Step 9: GT=(48.33, 18.04) | Pred=(38.16, 17.12) | Error=10.21
# Step 10: GT=(49.47, 18.74) | Pred=(41.41, 17.30) | Error=8.19
#
# Mean Error: 5.67, Max Error: 10.40

# %%
# Plotting prediction path
if 'predicted_coords' in locals(): # Only plot if prediction was successful
    plt.figure(figsize=(12, 8))

    # Get the last 'LOOK_BACK' actual data points from the *filtered* original data for input visualization
    last_input_data_orig_filtered = filtered_df[['x_snap', 'y_snap']].tail(LOOK_BACK).values

    plt.plot(original_df_for_plotting['x_snap'], original_df_for_plotting['y_snap'], 'b-', label='Original Data Path (Pre-filter)', alpha=0.6)
    plt.plot(last_input_data_orig_filtered[:, 0], last_input_data_orig_filtered[:, 1], 'g-o', markersize=5, label=f'Last {LOOK_BACK} Input Points (Post-filter)')
    plt.plot(predicted_coords[:, 0], predicted_coords[:, 1], 'r-x', markersize=8, label=f'Predicted Next {PREDICT_AHEAD_STEPS} Steps')

    if len(last_input_data_orig_filtered) > 0:
        plt.scatter(last_input_data_orig_filtered[-1, 0], last_input_data_orig_filtered[-1, 1], color='purple', s=100, zorder=5, label='Last Input Point')
    if len(predicted_coords) > 0:
        plt.scatter(predicted_coords[0, 0], predicted_coords[0, 1], color='orange', s=100, zorder=5, label='First Predicted Point')
        plt.scatter(predicted_coords[-1, 0], predicted_coords[-1, 1], color='red', s=100, zorder=5, label='Last Predicted Point')

    plt.title(f'BLE Path: Last {LOOK_BACK} Steps and Predicted Next {PREDICT_AHEAD_STEPS} Steps')
    plt.xlabel('X Coordinate')
    plt.ylabel('Y Coordinate')
    plt.legend()
    plt.grid(True)
    plt.gca().set_aspect('equal', adjustable='box')
    plot_path = os.path.join(output_result, 'prediction_path_plot.png')
    plt.savefig(plot_path)
    plt.close()
    print(f"  Prediction path plot saved at: {plot_path}")
else:
    print("  Prediction path plot skipped as no prediction was made.")
# Out:
#   Prediction path plot saved at: output_result/prediction_path_plot.png

# %%
# --- Plot per-step Euclidean distance errors ---
plt.figure(figsize=(10, 6))
plt.stem(range(1, PREDICT_AHEAD_STEPS + 1), errors, basefmt=" ")
# plt.plot(range(1, PREDICT_AHEAD_STEPS + 1), errors, marker='o', linestyle='-', color='red')
plt.title('Per-Step Euclidean Error (Ground Truth vs Prediction)')
plt.xlabel('Step')
plt.ylabel('Error (distance units)')
plt.grid(True)
plt.xticks(range(1, PREDICT_AHEAD_STEPS + 1))
plt.tight_layout()

error_plot_path = os.path.join(output_result, 'prediction_error_plot.png')
plt.savefig(error_plot_path)
plt.close()
print(f"  Error plot saved at: {error_plot_path}")
# Out:
#   Error plot saved at: output_result/prediction_error_plot.png

# %%
# --- Create Comparison DataFrame ---
comparison_df = pd.DataFrame({
    'Step': np.arange(1, PREDICT_AHEAD_STEPS + 1),
    'GT_x': true_coords[:, 0],
    'GT_y': true_coords[:, 1],
    'Pred_x': predicted_coords[:, 0],
    'Pred_y': predicted_coords[:, 1],
    'Error_Distance': errors
})

# --- Save to CSV ---
comparison_csv_path = os.path.join(output_result, 'ground_truth_vs_prediction.csv')
comparison_df.to_csv(comparison_csv_path, index=False)
print(f"✅ CSV saved to: {comparison_csv_path}")

# --- Plot Ground Truth vs Predicted Path ---
plt.figure(figsize=(10, 8))
plt.plot(true_coords[:, 0], true_coords[:, 1], 'go-', label='Ground Truth Path')
plt.plot(predicted_coords[:, 0], predicted_coords[:, 1], 'rx--', label='Predicted Path')

# Start & End markers
plt.scatter(true_coords[0, 0], true_coords[0, 1], color='green', s=100, label='GT Start', marker='o')
plt.scatter(true_coords[-1, 0], true_coords[-1, 1], color='darkgreen', s=100, label='GT End', marker='o')

plt.scatter(predicted_coords[0, 0], predicted_coords[0, 1], color='red', s=100, label='Pred Start', marker='x')
plt.scatter(predicted_coords[-1, 0], predicted_coords[-1, 1], color='darkred', s=100, label='Pred End', marker='x')

plt.title('Ground Truth vs Predicted Path (10 Steps)')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.legend()
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')

# Save the plot
comparison_plot_path = os.path.join(output_result, 'ground_truth_vs_prediction_plot.png')
plt.savefig(comparison_plot_path)
plt.close()

print(f"📈 Plot saved to: {comparison_plot_path}")
# Out:
# ✅ CSV saved to: output_result/ground_truth_vs_prediction.csv
# 📈 Plot saved to: output_result/ground_truth_vs_prediction_plot.png

# %%
# Historical path
original_path = original_df_for_plotting[['x_snap', 'y_snap']].values

plt.figure(figsize=(12, 8))

# Plot full trajectory
plt.plot(original_path[:, 0], original_path[:, 1], 'k-', alpha=0.3, label='History Trajectory')

# Plot ground truth and predicted paths
plt.plot(true_coords[:, 0], true_coords[:, 1], 'go-', label='Ground Truth (Next 10 Steps)')
plt.plot(predicted_coords[:, 0], predicted_coords[:, 1], 'rx--', label='Predicted Path')

# Draw filled area (polygon) between each GT and predicted point
for i in range(len(true_coords)-1):
    # Define polygon between GT[i] -> GT[i+1] and Pred[i] -> Pred[i+1]
    polygon_x = [true_coords[i, 0], true_coords[i+1, 0],
                 predicted_coords[i+1, 0], predicted_coords[i, 0]]
    polygon_y = [true_coords[i, 1], true_coords[i+1, 1],
                 predicted_coords[i+1, 1], predicted_coords[i, 1]]
    
    # Use alpha-shaded gray, or color by error if desired
    plt.fill(polygon_x, polygon_y, color='gray', alpha=0.3)

# Start and end points
plt.scatter(original_path[0, 0], original_path[0, 1], color='blue', s=100, label='Start (History)')
plt.scatter(original_path[-1, 0], original_path[-1, 1], color='navy', s=100, label='End (History)')
plt.scatter(true_coords[0, 0], true_coords[0, 1], color='green', s=100, label='GT Start', marker='o')
plt.scatter(true_coords[-1, 0], true_coords[-1, 1], color='darkgreen', s=100, label='GT End', marker='o')
plt.scatter(predicted_coords[0, 0], predicted_coords[0, 1], color='red', s=100, label='Pred Start', marker='x')
plt.scatter(predicted_coords[-1, 0], predicted_coords[-1, 1], color='darkred', s=100, label='Pred End', marker='x')

plt.title('Trajectory with Shaded Difference Between GT and Predicted Paths')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.legend()
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')

# Save the plot
filled_diff_plot_path = os.path.join(output_result, 'trajectory_filled_difference.png')
plt.savefig(filled_diff_plot_path)
plt.close()

print(f"✅ Saved shaded path difference plot at:\n{filled_diff_plot_path}")
# Out:
# ✅ Saved shaded path difference plot at:
# output_result/trajectory_filled_difference.png

# %%
# Historical path (already loaded earlier)
original_path = original_df_for_plotting[['x_snap', 'y_snap']].values

plt.figure(figsize=(12, 8))

# --- Plot history ---
plt.plot(original_path[:, 0], original_path[:, 1], 'k-', alpha=0.3, label='History Trajectory')

# --- Plot ground truth and predicted paths ---
plt.plot(true_coords[:, 0], true_coords[:, 1], 'go-', label='Ground Truth Path')
plt.plot(predicted_coords[:, 0], predicted_coords[:, 1], 'rx--', label='Predicted Path')

# --- Plot Euclidean error lines step-by-step ---
for i in range(len(true_coords)):
    plt.plot(
        [true_coords[i, 0], predicted_coords[i, 0]],
        [true_coords[i, 1], predicted_coords[i, 1]],
        color='orange', linestyle='-', linewidth=2, alpha=0.7,
        label='Error Line' if i == 0 else ""  # Show label only once
    )

# --- Mark Start/End points ---
plt.scatter(original_path[0, 0], original_path[0, 1], color='blue', s=100, label='Start (History)')
plt.scatter(original_path[-1, 0], original_path[-1, 1], color='navy', s=100, label='End (History)')
plt.scatter(true_coords[0, 0], true_coords[0, 1], color='green', s=100, label='GT Start', marker='o')
plt.scatter(true_coords[-1, 0], true_coords[-1, 1], color='red', s=100, label='GT End', marker='o')
plt.scatter(predicted_coords[0, 0], predicted_coords[0, 1], color='red', s=100, label='Pred Start', marker='x')
plt.scatter(predicted_coords[-1, 0], predicted_coords[-1, 1], color='darkred', s=100, label='Pred End', marker='x')

# --- Final formatting ---
plt.title('GT vs Predicted Path with Euclidean Error Lines')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.legend()
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')

# Save the plot
error_lines_plot_path = os.path.join(output_result, 'gt_vs_pred_error_lines.png')
plt.savefig(error_lines_plot_path)
plt.close()

print(f"✅ Saved plot with Euclidean error lines:\n{error_lines_plot_path}")
# Out:
# ✅ Saved plot with Euclidean error lines:
# output_result/gt_vs_pred_error_lines.png

# %%
# Create animation again but using actual real-world coordinate range for visualization
from matplotlib import animation 

# Define figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Plot historical path as background
ax.plot(original_path[:, 0], original_path[:, 1], 'k-', alpha=0.3, label='History Trajectory')

# Initialize animated lines
gt_line, = ax.plot([], [], 'go-', label='Ground Truth')
pred_line, = ax.plot([], [], 'rx--', label='Prediction')
error_lines = []

# Real-world coordinates: use min/max of all involved data
x_all = np.concatenate([original_path[:, 0], true_coords[:, 0], predicted_coords[:, 0]])
y_all = np.concatenate([original_path[:, 1], true_coords[:, 1], predicted_coords[:, 1]])

# Set axis limits based on data
ax.set_xlim(np.min(x_all) - 2, np.max(x_all) + 2)
ax.set_ylim(np.min(y_all) - 2, np.max(y_all) + 2)
ax.set_title('BLE Path Prediction vs Ground Truth (Real Map Coordinates)')
ax.set_xlabel('X Coordinate (meters)')
ax.set_ylabel('Y Coordinate (meters)')
ax.legend()
ax.grid(True)
ax.set_aspect('equal', adjustable='box')

# Update function for animation
def update_real(frame):
    gt_line.set_data(true_coords[:frame+1, 0], true_coords[:frame+1, 1])
    pred_line.set_data(predicted_coords[:frame+1, 0], predicted_coords[:frame+1, 1])

    for line in error_lines:
        line.remove()
    error_lines.clear()

    for i in range(frame + 1):
        error_line, = ax.plot(
            [true_coords[i, 0], predicted_coords[i, 0]],
            [true_coords[i, 1], predicted_coords[i, 1]],
            color='orange', linestyle='-', linewidth=2, alpha=0.7
        )
        error_lines.append(error_line)

    return [gt_line, pred_line] + error_lines

# Create animation
ani_real = animation.FuncAnimation(fig, update_real, frames=PREDICT_AHEAD_STEPS, interval=800, blit=True)

# Save to GIF again using real-world coordinate scaling
real_map_gif_path = os.path.join(output_result, 'gt_vs_pred_real_coords.gif')
ani_real.save(real_map_gif_path, writer='pillow')

real_map_gif_path
# Out:
# 'output_result/gt_vs_pred_real_coords.gif'
